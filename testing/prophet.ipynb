# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("sales_data.csv")
df.rename(columns={"date": "ds", "sales": "y"}, inplace=True)

# Inisialisasi model Prophet
model = Prophet()
model.fit(df)

# Membuat data untuk prediksi (180 hari ke depan)
future = model.make_future_dataframe(periods=180)

# Melakukan prediksi
forecast = model.predict(future)

# Visualisasi hasil prediksi
fig = model.plot(forecast)
plt.show()

# Menampilkan komponen tren, musiman, dan yearly effect
fig2 = model.plot_components(forecast)
plt.show()
# Out:
# 14:43:32 - cmdstanpy - INFO - Chain [1] start processing
# 14:43:32 - cmdstanpy - INFO - Chain [1] done processing
